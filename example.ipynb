# %%
from ladder import Ladder, StraightLadder
from draw_matplotlib import LadderDrawer

# %%
ladder = Ladder()

# %%
l1, n11, n12 = ladder.add_cycle("1", "11", "12")
l2, n21, n22, n23, n24, n25 = ladder.add_cycle("2", "21", "22", "23", "24", "25")
l3, n31, n32, n33, n34, n35 = ladder.add_cycle("3", "31", "32", "33", "34", "35")
l4, n41, n42 = ladder.add_cycle("4", "41", "42")

# %%
n11.hori_connect(n24)
n12.hori_connect(n22)
n21.hori_connect(n35)
n23.hori_connect(n33)
n25.hori_connect(n31)
n41.hori_connect(n34)
n42.hori_connect(n32)

# %%
ladder.fix()

# %%
ladder.global_dynamism()
# Out:
# 0.4781341324086531

# %%
ladder2 = StraightLadder(3, [0, 1, 0])

# %%
ladder2[0, 2].hori_after, ladder2[0, 2].hori_before
# Out:
# (Node(under_under_under_1), Node(under_under_under_1))

# %%
ladder2.fix()
ladder2.global_dynamism()
# Out:
# 0.09523809523809527

# %%
ladder2.unfix()
ladder2.twist(0, 1, 2)
ladder2.fix()
ladder2.global_dynamism()
# Out:
# 0.39999999999999997

# %%
drawer = LadderDrawer(ladder2)
drawer.draw_ghost_leg_ellipse(check_point=True)
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
ladder2[0, 2].hori_after, ladder2[0, 2].hori_before
# Out:
# (Node(under_1), Node(under_1))

# %%
ladder3 = StraightLadder(4, [0, 2, 1, 0, 2])

# %%
LadderDrawer(ladder3).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
ladder2.unfix()
ladder2[0, 2].solo()
ladder2[1, 2].solo()
ladder2[1, 0].hori_connect(ladder2[2, 1])
ladder2[2, 0].hori_connect(ladder2[1, 2])
ladder2.fix()
drawer = LadderDrawer(ladder2)
drawer.draw_ghost_leg_ellipse(check_point=True, shift=True)
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
ladder2.global_dynamism()
# Out:
# 0.3333333333333333

# %%
l = StraightLadder(3, [0, 1, 0])

# %%
LadderDrawer(l).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
l.fix()
l.global_dynamism()
# Out:
# 0.09523809523809527

# %%
l.unfix()
l.twist(0, 1, 2)
l.fix()

# %%
LadderDrawer(l).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
l.global_dynamism()
# Out:
# 0.39999999999999997

# %%
LadderDrawer(ladder3).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
ladder3.fix()
ladder3.global_dynamism()
# Out:
# 0.2285714285714285

# %%
ladder3.unfix()
ladder3.twist(0, 1, 2)
ladder3.insert_under(ladder3[1, 2], ladder3[2, 0], "aa", "bb")
ladder3.fix()
ladder3.global_dynamism()
# Out:
# 0.3900231523830231

# %%
LadderDrawer(ladder3).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)
