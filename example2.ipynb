# %%
from ladder import Ladder, StraightLadder
from draw_matplotlib import LadderDrawer

# %%
l1 = StraightLadder(6, [2, 1, 3, 0, 2, 4, 1, 3, 2])
LadderDrawer(l1).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
l1.fix()
l1.dynamism()
# Out:
# 0.02133442931431177

# %%
l1.unfix()
l1.twist(1, 1, 3)
l1.twist(2, 1, 5)
l1.twist(4, 1, 3)
l1.fix()

# %%
LadderDrawer(l1).draw_ghost_leg()
# Out:
# (<Figure size 500x500 with 1 Axes>, <Axes: >)

# %%
l1.dynamism()
# Out:
# 0.39236176701405273
